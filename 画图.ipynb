# %% [markdown]
# <a href="https://colab.research.google.com/github/Frankchensir/api-guides/blob/master/%E7%94%BB%E5%9B%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np               #加载numpy模块
import matplotlib.pyplot as plt  #加载pyplot
X=np.linspace(0,2*np.pi,100)
y=1.5*np.sin(2*X-1)
plt.plot(X,y,c='b')
plt.show()

# %%
import hedera

secret, mnemonic = hedera.SecretKey.generate("")
public = secret.public

print(f"secret   = {secret}")
print(f"mnemonic = {mnemonic}")
print(f"public   = {public}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5963a2d77174> in <module>()
# ----> 1 import hedera
#       2
#       3 secret, mnemonic = hedera.SecretKey.generate("")
#       4 public = secret.public
#       5
#
# ModuleNotFoundError: No module named 'hedera'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
